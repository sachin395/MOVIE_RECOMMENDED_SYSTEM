# %%
import pandas as pd

# %%
df = pd.read_csv("fico.csv")

# %%
df.head(5)
# Out:
#    acct_id FICO
# 0        1  768
# 1        2  850
# 2        3  677
# 3        4  843
# 4        5  796

# %%
df.head(15)
# Out:
#     acct_id FICO
# 0         1  768
# 1         2  850
# 2         3  677
# 3         4  843
# 4         5  796
# 5         6  669
# 6         7  805
# 7         8  850
# 8         9  838
# 9        10  850
# 10       11  NaN
# 11       12  794
# 12       13  832
# 13       14  777
# 14       15  809

# %%
df.columns
# Out:
# Index(['acct_id', 'FICO'], dtype='object')

# %%
type(df['FICO'][10])
# Out:
# float

# %%
df['FICO'][0] = int(df['FICO'][0])
# Out:
# C:\Users\Siddhant k prasad\AppData\Local\Temp/ipykernel_12472/702124221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FICO'][0] = int(df['FICO'][0])

# %%
for i in range(len(df['FICO'])):
    try:
        df['FICO'][i] = int(df['FICO'][i])
    except:
        df['FICO'][i] = None
        print("excwption occur")
# Out:
# C:\Users\Siddhant k prasad\AppData\Local\Temp/ipykernel_12472/642867782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FICO'][i] = int(df['FICO'][i])
# C:\Users\Siddhant k prasad\AppData\Local\Temp/ipykernel_12472/642867782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FICO'][i] = None
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# excwption occur
# ...

# %%
df.shape

# %%
fdd = df

# %%
ris = fdd.dropna(axis=0)

# %%
ris.head(20)

# %%
ris.to_csv('sachinfinal.csv')
